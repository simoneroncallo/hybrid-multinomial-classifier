# %%
for a in ["classical", "quantum"]:
    for m in ["tree", "one_vs_rest", "one_vs_one"]:
        for d in ["MNIST", "Fashion", "CIFAR"]:
            # !python3 main.py --dataset {d} --mode {m} --arch {a}

# %%
# !python3 main.py --dataset CIFAR --mode one_vs_rest --arch quantum
# Out:
# # --- START --- #
# Settings <- quantum, one_vs_rest, CIFAR
# 100%|============================================| 6/6 [39:54<00:00, 399.09s/it]
# Average accuracy of 46.2%
# Runtime of 2398.42s (0.67h)
# # ---  END  --- #

# %%
# !python3 main.py --dataset CIFAR --mode one_vs_rest --arch quantum
# Out:
# # --- START --- #
# Settings <- quantum, one_vs_rest, CIFAR
# 100%|============================================| 6/6 [15:30<00:00, 155.11s/it]
# Average accuracy of 45.3%
# Runtime of 933.51s (0.26h)
# # ---  END  --- #

# %%
# !python3 main.py --dataset CIFAR --mode one_vs_rest --arch classical
# Out:
# # --- START --- #
# Settings <- classical, one_vs_rest, CIFAR
# 100%|==========================================| 6/6 [1:05:54<00:00, 659.11s/it]
# Average accuracy of 49.3%
# Runtime of 3957.63s (1.10h)
# # ---  END  --- #

# %%
# !python3 main.py --dataset CIFAR --mode one_vs_rest --arch quantum
# Out:
# # --- START --- #
# Settings <- quantum, one_vs_rest, CIFAR
# 100%|============================================| 6/6 [18:34<00:00, 185.73s/it]
# Average accuracy of 44.8%
# Runtime of 1117.25s (0.31h)
# # ---  END  --- #

# %%
# !python3 main.py --dataset CIFAR --mode one_vs_rest --arch classical
# Out:
# # --- START --- #
# Settings <- classical, one_vs_rest, CIFAR
# 100%|==========================================| 6/6 [1:02:20<00:00, 623.42s/it]
# Average accuracy of 47.6%
# Runtime of 3743.53s (1.04h)
# # ---  END  --- #
