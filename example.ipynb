# %%
for a in ["classical", "quantum"]:
    for m in ["tree", "one_vs_rest", "one_vs_one"]:
        for d in ["MNIST", "Fashion", "CIFAR"]:
            # !python3 main.py --dataset {d} --mode {m} --arch {a}

# %%
# !python3 main.py --dataset MNIST --mode tree --arch quantum
# Out:
# # --- START --- #
# Settings <- quantum, tree, MNIST
# 100%|============================================| 5/5 [09:00<00:00, 108.05s/it]
# Average accuracy of 97.4%
# Runtime of 541.77s (0.15h)
# # ---  END  --- #

# %%
# !python3 main.py --dataset MNIST --mode tree --arch quantum
# Out:
# # --- START --- #
# Settings <- quantum, tree, MNIST
# 100%|============================================| 5/5 [17:44<00:00, 212.97s/it]
# Average accuracy of 97.6%
# Runtime of 1066.54s (0.30h)
# # ---  END  --- #

# %%
# !python3 main.py --dataset CIFAR --mode one_vs_rest --arch classical
# Out:
# # --- START --- #
# Settings <- classical, one_vs_rest, CIFAR
# 100%|==========================================| 6/6 [1:15:59<00:00, 759.87s/it]
# Average accuracy of 46.2%
# Runtime of 4561.79s (1.27h)
# # ---  END  --- #

# %%
# With standardization
# !python3 main.py --dataset MNIST --mode tree --arch quantum
# Out:
# # --- START --- #
# Settings <- quantum, tree, MNIST
# 100%|============================================| 5/5 [17:40<00:00, 212.04s/it]
# Average accuracy of 88.8%
# Runtime of 1061.63s (0.29h)
# # ---  END  --- #

# %%
# !python3 main.py --dataset CIFAR --mode tree --arch quantum
# Out:
# # --- START --- #
# Settings <- quantum, tree, CIFAR
# 100%|============================================| 5/5 [10:08<00:00, 121.75s/it]
# Average accuracy of 40.5%
# Runtime of 611.62s (0.17h)
# # ---  END  --- #
