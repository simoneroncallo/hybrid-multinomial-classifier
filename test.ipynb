# %%
# !python3 main.py --dataset MNIST --mode tree --arch classical
# !python3 main.py --dataset Fashion --mode tree --arch classical
# !python3 main.py --dataset CIFAR --mode tree --arch classical
# Out:
# Legend
# Models 0 -> [5, 2, 0, 1, 3, 4]
# Models 1 -> [5, 2, 0]
# Models 2 -> [1, 3, 4]
# Models 3 -> [2, 0]
# Models 4 -> [3, 4]
# 100%|█████████████████████████████████████████████| 5/5 [00:34<00:00,  6.82s/it]
# Figure(8000x1600)
# Runtime of 35.38s (0.01h)
# Legend
# Models 0 -> [5, 2, 0, 1, 3, 4]
# Models 1 -> [5, 2, 0]
# Models 2 -> [1, 3, 4]
# Models 3 -> [2, 0]
# Models 4 -> [3, 4]
# 100%|█████████████████████████████████████████████| 5/5 [00:29<00:00,  5.93s/it]
# Figure(8000x1600)
# Runtime of 31.09s (0.01h)
# /usr/local/lib/python3.13/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Legend
# Models 0 -> [5, 2, 0, 1, 3, 4]
# Models 1 -> [5, 2, 0]
# Models 2 -> [1, 3, 4]
# Models 3 -> [2, 0]
# Models 4 -> [3, 4]
# ...

# %%
# !python3 main.py --dataset MNIST --mode one_vs_rest --arch classical
# !python3 main.py --dataset Fashion --mode one_vs_rest --arch classical
# !python3 main.py --dataset CIFAR --mode one_vs_rest --arch classical
# Out:
# 100%|█████████████████████████████████████████████| 6/6 [01:15<00:00, 12.62s/it]
# Figure(8000x1600)
# Runtime of 76.54s (0.02h)
# 100%|█████████████████████████████████████████████| 6/6 [01:01<00:00, 10.20s/it]
# Figure(8000x1600)
# Runtime of 62.08s (0.02h)
# /usr/local/lib/python3.13/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# 100%|█████████████████████████████████████████████| 6/6 [01:19<00:00, 13.24s/it]
# Figure(8000x1600)
# Runtime of 81.45s (0.02h)

# %%
# !python3 main.py --dataset MNIST --mode one_vs_one --arch classical
# !python3 main.py --dataset Fashion --mode one_vs_one --arch classical
# !python3 main.py --dataset CIFAR --mode one_vs_one --arch classical
# Out:
# 100%|███████████████████████████████████████████| 15/15 [00:52<00:00,  3.48s/it]
# Figure(8000x1600)
# Runtime of 53.09s (0.01h)
# 100%|███████████████████████████████████████████| 15/15 [00:57<00:00,  3.86s/it]
# Figure(8000x1600)
# Runtime of 58.79s (0.02h)
# /usr/local/lib/python3.13/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# 100%|███████████████████████████████████████████| 15/15 [00:57<00:00,  3.85s/it]
# Figure(8000x1600)
# Runtime of 59.83s (0.02h)
